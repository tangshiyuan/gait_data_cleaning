# %%
import pandas as pd
df = pd.read_csv("Sub1LF_TreadWalk_signal.csv")
print(df.head())
# Out:
#     accX    accY   accZ
# 0 -2.196 -11.765 -1.569
# 1 -2.510 -10.353 -2.039
# 2 -2.353 -10.824 -2.510
# 3 -1.882 -10.667 -2.667
# 4 -1.412 -10.353 -2.824

# %%
df.index
# Out:
# RangeIndex(start=0, stop=55931, step=1)

# %% [markdown]
# Converting index to a column
# https://stackoverflow.com/questions/20461165/how-to-convert-pandas-index-in-a-dataframe-to-a-column

# %%
df.reset_index(level=0, inplace=True)

# %%
df.head()
# Out:
#    index   accX    accY   accZ
# 0      0 -2.196 -11.765 -1.569
# 1      1 -2.510 -10.353 -2.039
# 2      2 -2.353 -10.824 -2.510
# 3      3 -1.882 -10.667 -2.667
# 4      4 -1.412 -10.353 -2.824

# %%
from ggplot import *

ggplot(aes(x='index', y='accX'), data=df) +\
    geom_line() +\
    stat_smooth(colour='blue', span=0.2)
# Out:
# <ggplot: (-9223371901392899370)>

# %%
ggplot(aes(x='index'), data=df) +\
    geom_line(aes(y='accX'), color='blue') +\
    geom_line(aes(y='accY'), color='red') +\
    geom_line(aes(y='accZ'), color='green') +\
    stat_smooth(colour='white', span=0.2)
# Out:
# <ggplot: (-9223371901392901688)>

# %%
ggplot(aes(x='index'), data=df) +\
    geom_line(aes(y='accX'), color='blue') +\
    geom_line(aes(y='accY'), color='red') +\
    geom_line(aes(y='accZ'), color='green') +\
    scale_x_continuous(name="index range", limits=(0,1000))
# Out:
# <ggplot: (-9223371901340510748)>

# %%
import pandas as pd
df_HS = pd.read_csv("Sub1LF_TreadWalk_HS.csv", header=None)
df_TO = pd.read_csv("Sub1LF_TreadWalk_TO.csv", header=None)
print(df_HS.head())
# Out:
#      0
# 0  102
# 1  237
# 2  373
# 3  510
# 4  647

# %%
df_HS.shape
# Out:
# (456, 1)

# %%
rename_list = ['index']

# %%
df_HS.columns = rename_list
df_TO.columns = rename_list

# %%
df_HS.columns
# Out:
# Index(['index'], dtype='object')

# %%
list(df_HS)
# Out:
# ['index']

# %%
df_HS.head()
# Out:
#    index
# 0    102
# 1    237
# 2    373
# 3    510
# 4    647

# %%
df_TO.head()
# Out:
#    index
# 0     46
# 1    182
# 2    320
# 3    454
# 4    591

# %%
import numpy as np
#df['HS'] = np.NaN
#df['TO'] = np.NaN
df['HS'] = 0
df['TO'] = 0
df['HS_mark'] = np.NaN
df['TO_mark'] = np.NaN

# %%
df.head()
# Out:
#    index   accX    accY   accZ  HS  TO  HS_mark  TO_mark
# 0      0 -2.196 -11.765 -1.569   0   0      NaN      NaN
# 1      1 -2.510 -10.353 -2.039   0   0      NaN      NaN
# 2      2 -2.353 -10.824 -2.510   0   0      NaN      NaN
# 3      3 -1.882 -10.667 -2.667   0   0      NaN      NaN
# 4      4 -1.412 -10.353 -2.824   0   0      NaN      NaN

# %%
rename_list = df.columns.values

# %%
rename_list.tolist()
rename_list[0] = 'id'

# %%
rename_list
# Out:
# array(['id', 'accX', 'accY', 'accZ', 'HS', 'TO', 'HS_mark', 'TO_mark'],
#       dtype=object)

# %%
df.columns = rename_list

# %%
df.loc[0]
# Out:
# id          0.000
# accX       -2.196
# accY      -11.765
# accZ       -1.569
# HS          0.000
# TO          0.000
# HS_mark       NaN
# TO_mark       NaN
# Name: 0, dtype: float64

# %%
df['index'].loc[0]
# Out:
# 0

# %%
for i in df_HS.index:
    #print(df_HS['index'][i])
    indx = df_HS['index'][i]
    #print(df['index'].loc[indx])
    df['HS'].loc[indx] = 1
    df['HS_mark'].loc[indx] = 30
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in df_TO.index:
    indx = df_TO['index'][i]
    df['TO'].loc[indx] = 1
    df['TO_mark'].loc[indx] = -30
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.loc[40:105]
# Out:
#       id    accX    accY    accZ  HS  TO  HS_mark  TO_mark
# 40    40  -0.627 -18.353  -0.471   0   0      NaN      NaN
# 41    41   2.667 -20.235  -2.353   0   0      NaN      NaN
# 42    42   2.196 -21.176  -3.294   0   0      NaN      NaN
# 43    43   1.255 -21.176  -4.549   0   0      NaN      NaN
# 44    44   3.137 -20.863  -4.235   0   0      NaN      NaN
# 45    45   2.980 -20.392  -3.451   0   0      NaN      NaN
# 46    46   4.078 -19.922  -8.000   0   1      NaN    -30.0
# 47    47   4.392 -20.392  -9.569   0   0      NaN      NaN
# 48    48   3.608 -21.647  -9.098   0   0      NaN      NaN
# 49    49   1.725 -20.863  -8.941   0   0      NaN      NaN
# 50    50  -0.471 -20.235  -8.314   0   0      NaN      NaN
# 51    51  -4.549 -14.588 -10.196   0   0      NaN      NaN
# 52    52  -4.392 -12.078  -8.941   0   0      NaN      NaN
# 53    53   1.569  -8.784  -4.392   0   0      NaN      NaN
# 54    54   2.353  -8.627  -5.647   0   0      NaN      NaN
# 55    55   8.627 -11.451   1.098   0   0      NaN      NaN
# 56    56   9.725  -9.098   1.098   0   0      NaN      NaN
# 57    57  10.196  -4.235   2.039   0   0      NaN      NaN
# 58    58   6.902  -2.196   2.039   0   0      NaN      NaN
# 59    59   5.176  -0.941   2.196   0   0      NaN      NaN
# 60    60   5.176  -0.941   1.882   0   0      NaN      NaN
# 61    61   5.647  -1.412   2.039   0   0      NaN      NaN
# 62    62   6.431  -2.824   2.039   0   0      NaN      NaN
# 63    63   6.118  -3.294   2.196   0   0      NaN      NaN
# 64    64   4.078  -3.922   1.882   0   0      NaN      NaN
# 65    65   2.667  -4.235   0.784   0   0      NaN      NaN
# 66    66   2.196  -4.863   0.627   0   0      NaN      NaN
# 67    67   2.667  -5.804   0.000   0   0      NaN      NaN
# 68    68   3.451  -6.745  -0.157   0   0      NaN      NaN
# 69    69   2.824  -8.157  -0.627   0   0      NaN      NaN
# ..   ...     ...     ...     ...  ..  ..      ...      ...
# 76    76  -2.980 -14.118  -6.902   0   0      NaN      NaN
# 77    77  -3.765 -15.216  -6.902   0   0      NaN      NaN
# 78    78  -5.961 -17.412  -8.941   0   0      NaN      NaN
# 79    79  -7.216 -18.039  -9.725   0   0      NaN      NaN
# 80    80 -10.196 -18.824 -11.765   0   0      NaN      NaN
# 81    81 -12.863 -19.608 -13.804   0   0      NaN      NaN
# 82    82 -13.647 -19.922 -13.961   0   0      NaN      NaN
# 83    83 -13.333 -20.392 -13.647   0   0      NaN      NaN
# 84    84 -13.176 -20.392 -13.647   0   0      NaN      NaN
# 85    85 -13.020 -19.922 -13.490   0   0      NaN      NaN
# 86    86 -13.647 -19.608 -13.333   0   0      NaN      NaN
# 87    87 -15.216 -17.412 -13.804   0   0      NaN      NaN
# 88    88 -15.686 -15.373 -13.961   0   0      NaN      NaN
# 89    89 -16.941 -11.294 -15.373   0   0      NaN      NaN
# 90    90 -19.294  -7.843 -16.157   0   0      NaN      NaN
# 91    91 -20.549  -5.804 -15.686   0   0      NaN      NaN
# 92    92 -22.745  -4.235 -13.647   0   0      NaN      NaN
# 93    93 -22.902  -4.549 -12.078   0   0      NaN      NaN
# 94    94 -20.549  -5.490 -10.353   0   0      NaN      NaN
# 95    95 -18.980  -5.647 -10.196   0   0      NaN      NaN
# 96    96 -15.373  -6.745 -10.039   0   0      NaN      NaN
# 97    97 -14.588  -7.216 -10.039   0   0      NaN      NaN
# 98    98 -13.020  -8.314  -9.569   0   0      NaN      NaN
# 99    99 -11.922  -8.784  -8.471   0   0      NaN      NaN
# 100  100 -10.196  -9.882  -8.157   0   0      NaN      NaN
# 101  101   8.471 -18.353   2.196   0   0      NaN      NaN
# 102  102  21.961 -19.922  10.039   1   0     30.0      NaN
# 103  103  50.667 -17.412   8.000   0   0      NaN      NaN
# 104  104  37.961 -13.647   3.765   0   0      NaN      NaN
# 105  105  -8.784  -9.412   0.314   0   0      NaN      NaN
#
# [66 rows x 8 columns]

# %%
#import matplotlib.pyplot as plt

dataText=pd.DataFrame.from_items([('x',[4]),('y',[7]),('text',['R^2'])])

ggplot(aes(x='id'), data=df) +\
    geom_line(aes(y='accX'), color='blue') +\
    geom_line(aes(y='accY'), color='red') +\
    geom_line(aes(y='accZ'), color='green') +\
    geom_point(aes(y='HS_mark'), color='steelblue', size=100) +\
    geom_point(aes(y='TO_mark'), color='slateblue', size=100) +\
    scale_x_continuous(name="index range", limits=(0,500)) +\
    scale_y_continuous(limits=(-40,40)) +\
    ggtitle('AccX') +\
    xlab('index') +\
    ylab('Acceleration')
# Out:
# <ggplot: (-9223371901246437397)>

# %%
#import matplotlib.pyplot as plt

dataText=pd.DataFrame.from_items([('x',[4]),('y',[7]),('text',['R^2'])])

ggplot(aes(x='id'), data=df) +\
    geom_line(aes(y='accX'), color='blue') +\
    geom_line(aes(y='accY'), color='red') +\
    geom_line(aes(y='accZ'), color='green') +\
    geom_point(aes(y='HS_mark'), color='steelblue', size=100) +\
    geom_point(aes(y='TO_mark'), color='slateblue', size=100) +\
    scale_x_continuous(name="index range", limits=(0,500)) +\
    scale_y_continuous(limits=(-40,40)) +\
    ggtitle('AccX') +\
    xlab('index') +\
    ylab('Acceleration') +\
    geom_text(aes(x='x', y='y', label='text'), data=dataText)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ggplot\aes.py in _evaluate_expressions(self, data)
#     101                 try:
# --> 102                     new_val = env.eval(item, inner_namespace=data)
#     103                     data[item] = new_val
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'TO_mark' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     691                 type_pprinters=self.type_printers,
#     692                 deferred_pprinters=self.deferred_printers)
# --> 693             printer.pretty(obj)
#     694             printer.flush()
#     695             return stream.getvalue()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     378                             if callable(meth):
#     379                                 return meth(obj, self, cycle)
# --> 380             return _default_pprint(obj, self, cycle)
#     381         finally:
#     382             self.end_group()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _default_pprint(obj, p, cycle)
#     493     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     494         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 495         _repr_pprint(obj, p, cycle)
#     496         return
#     497     p.begin_group(1, '<')
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     691     """A pprint that just redirects to the normal repr function."""
#     692     # Find newlines and replace them with p.break_()
# --> 693     output = repr(obj)
#     694     for idx,output_line in enumerate(output.splitlines()):
#     695         if idx:
#
# ~\Anaconda3\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# ~\Anaconda3\lib\site-packages\ggplot\ggplot.py in make(self)
#     634                         if kwargs==False:
#     635                             continue
# --> 636                         layer.plot(ax, facetgroup, self._aes, **kwargs)
#     637
#     638             self.apply_limits()
#
# ~\Anaconda3\lib\site-packages\ggplot\geoms\geom_text.py in plot(self, ax, data, _aes)
#      35
#      36     def plot(self, ax, data, _aes):
# ---> 37         (data, _aes) = self._update_data(data, _aes)
#      38         params = self._get_plot_args(data, _aes)
#      39         variables = _aes.data
#
# ~\Anaconda3\lib\site-packages\ggplot\geoms\geom.py in _update_data(self, data, _aes)
#      41                 data = _aes.handle_identity_values(data)
#      42         if 'data' in self.params:
# ---> 43             data = _aes._evaluate_expressions(self.params['data'])
#      44             data = _aes.handle_identity_values(data)
#      45
#
# ~\Anaconda3\lib\site-packages\ggplot\aes.py in _evaluate_expressions(self, data)
#     108                     for match in matches:
#     109                         msg += "    - %s\n" % match
# --> 110                     raise Exception(msg)
#     111         return data
#     112
#
# Exception: Invalid column: 'TO_mark'
# did you mean one of the following:

# %%
dataText.head()
# Out:
#    x  y text
# 0  4  7  R^2

# %%
#plt.figure()
df.plot('index','accX')
plt.show()

# %%
df.to_csv('output.csv', index = False)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
#        1.41414141, 1.43434343, 1.45454545, 1.47474747, 1.49494949,
#        1.51515152, 1.53535354, 1.55555556, 1.57575758, 1.5959596 ,
#        1.61616162, 1.63636364, 1.65656566, 1.67676768, 1.6969697 ,
#        1.71717172, 1.73737374, 1.75757576, 1.77777778, 1.7979798 ,
#        1.81818182, 1.83838384, 1.85858586, 1.87878788, 1.8989899 ,
#        1.91919192, 1.93939394, 1.95959596, 1.97979798, 2.        ])
